# %%
"""
Entry point for Phase 2: MhaElmClassifier + metaheuristics experiments.
"""

from data_mha import load_sleep_apnea_data
from experiment_mha import run_mha_elm_experiments


def main():
    print("=== Phase 2: MhaElmClassifier + Metaheuristics ===")
    print("Loading sleep apnea data...")
    X_train, X_test, y_train, y_test, scaler_X, le_y = load_sleep_apnea_data()
    dataset_name = "sleep_apnea"   # used in file names
    
    print("Starting metaheuristic optimization experiments...\n")
    run_mha_elm_experiments(X_train, X_test, y_train, y_test, dataset_name)
    
    print("\nAll experiments finished.")
    #print(f"Results saved under: {RESULTS_ROOT.resolve()}")


if __name__ == "__main__":
    main()

# %%
from intelelm import MhaElmClassifier
print(MhaElmClassifier.SUPPORTED_OPTIMIZERS)
# Look for 'DS_GWO' in the printed list
